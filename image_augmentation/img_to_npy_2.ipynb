# %%
# %cd C:\Users\migue\improved-bagan-gp-practice\images_to_npy_dataset
# Out:
# C:\Users\migue\improved-bagan-gp-practice\images_to_npy_dataset

# %%
import tensorflow as tf

# %%
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Found GPU at: /device:GPU:0

# %%
# !python img_to_npy.py --input_height=240 --input_width=240 --classes=3
# Out:
# -------------------------------------
# 3.9.19 (main, Mar 21 2024, 17:21:27) [MSC v.1916 64 bit (AMD64)]
# -------------------------------------
#  Command line options:
# --image_dir     :  image_dir
# --label_file    :  val.txt
# --classes       :  3
# --input_height  :  240
# --input_width   :  240
# --input_chans   :  3
# --resize        :  False
# --normalize     :  False
# --one_hot       :  False
# --compress      :  False
# --output_file   :  dataset.npz
# -------------------------------------
#  x shape: (4248, 240, 240, 3)
#  x data type: uint8
#  y shape: (4248,)
#  y data type: uint8
#  Saved to dataset.npz

# %%
import numpy as np
train_data = np.load('dataset.npz')
x_train = train_data['x']
y_train = train_data['y']

# %%
print(x_train.shape) 
print(y_train.shape)
# Out:
# (4248, 240, 240, 3)
# (4248,)

# %%
import matplotlib.pyplot as plt
plt.imshow(x_train[1800])
